# %% [markdown]
# # 1. Setting Up

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk import ConditionalFreqDist
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # 2. Loading the Dataset

# %% [markdown]
# We will be analyzing the dataset of the inaugural speeches by US presidents. Let's explore the dataset.

# %%
import nltk
nltk.download("inaugural")

from nltk.corpus import inaugural
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\Anna\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %%
raw_data = []
for fileid in inaugural.fileids():
    raw_data.append([fileid, " ".join(inaugural.words(fileid))])
data = pd.DataFrame(raw_data, columns=["File ID", "Text"])
data
# Out:
#                 File ID                                               Text
# 0   1789-Washington.txt  Fellow - Citizens of the Senate and of the Hou...
# 1   1793-Washington.txt  Fellow citizens , I am again called upon by th...
# 2        1797-Adams.txt  When it was first perceived , in early times ,...
# 3    1801-Jefferson.txt  Friends and Fellow Citizens : Called upon to u...
# 4    1805-Jefferson.txt  Proceeding , fellow citizens , to that qualifi...
# 5      1809-Madison.txt  Unwilling to depart from examples of the most ...
# 6      1813-Madison.txt  About to add the solemnity of an oath to the o...
# 7       1817-Monroe.txt  I should be destitute of feeling if I was not ...
# 8       1821-Monroe.txt  Fellow citizens , I shall not attempt to descr...
# 9        1825-Adams.txt  In compliance with an usage coeval with the ex...
# 10     1829-Jackson.txt  Fellow citizens , about to undertake the arduo...
# 11     1833-Jackson.txt  Fellow citizens , the will of the American peo...
# 12    1837-VanBuren.txt  Fellow citizens : The practice of all my prede...
# 13    1841-Harrison.txt  Called from a retirement which I had supposed ...
# 14        1845-Polk.txt  Fellow citizens , without solicitation on my p...
# 15      1849-Taylor.txt  Elected by the American people to the highest ...
# 16      1853-Pierce.txt  My Countrymen , It a relief to feel that no he...
# 17    1857-Buchanan.txt  Fellow citizens , I appear before you this day...
# 18     1861-Lincoln.txt  Fellow - Citizens of the United States : In co...
# 19     1865-Lincoln.txt  Fellow - Countrymen : At this second appearing...
# 20       1869-Grant.txt  Citizens of the United States : Your suffrages...
# 21       1873-Grant.txt  Fellow - Citizens : Under Providence I have be...
# 22       1877-Hayes.txt  Fellow citizens , we have assembled to repeat ...
# 23    1881-Garfield.txt  Fellow - Citizens : We stand to - day upon an ...
# 24   1885-Cleveland.txt  Fellow citizens , in the presence of this vast...
# 25    1889-Harrison.txt  Fellow - Citizens , there is no constitutional...
# 26   1893-Cleveland.txt  My Fellow citizens , in obedience of the manda...
# 27    1897-McKinley.txt  Fellow citizens , In obedience to the will of ...
# 28    1901-McKinley.txt  My fellow - citizens , when we assembled here ...
# 29   1905-Roosevelt.txt  My fellow citizens , no people on earth have m...
# 30        1909-Taft.txt  My fellow citizens : Anyone who has taken the ...
# 31      1913-Wilson.txt  There has been a change of government . It beg...
# 32      1917-Wilson.txt  My Fellow citizens : The four years which have...
# 33     1921-Harding.txt  My Countrymen : When one surveys the world abo...
# 34    1925-Coolidge.txt  My countrymen , no one can contemplate current...
# 35      1929-Hoover.txt  My Countrymen : This occasion is not alone the...
# 36   1933-Roosevelt.txt  I am certain that my fellow Americans expect t...
# 37   1937-Roosevelt.txt  When four years ago we met to inaugurate a Pre...
# 38   1941-Roosevelt.txt  On each national day of inauguration since 178...
# 39   1945-Roosevelt.txt  Chief Justice , Mr . Vice President , my frien...
# 40      1949-Truman.txt  Mr . Vice President , Mr . Chief Justice , and...
# 41  1953-Eisenhower.txt  My friends , before I begin the expression of ...
# 42  1957-Eisenhower.txt  The Price of Peace Mr . Chairman , Mr . Vice P...
# 43     1961-Kennedy.txt  Vice President Johnson , Mr . Speaker , Mr . C...
# 44     1965-Johnson.txt  My fellow countrymen , on this occasion , the ...
# 45       1969-Nixon.txt  Senator Dirksen , Mr . Chief Justice , Mr . Vi...
# 46       1973-Nixon.txt  Mr . Vice President , Mr . Speaker , Mr . Chie...
# 47      1977-Carter.txt  For myself and for our Nation , I want to than...
# 48      1981-Reagan.txt  Senator Hatfield , Mr . Chief Justice , Mr . P...
# 49      1985-Reagan.txt  Senator Mathias , Chief Justice Burger , Vice ...
# 50        1989-Bush.txt  Mr . Chief Justice , Mr . President , Vice Pre...
# 51     1993-Clinton.txt  My fellow citizens , today we celebrate the my...
# 52     1997-Clinton.txt  My fellow citizens : At this last presidential...
# 53        2001-Bush.txt  President Clinton , distinguished guests and m...
# 54        2005-Bush.txt  Vice President Cheney , Mr . Chief Justice , P...
# 55       2009-Obama.txt  My fellow citizens : I stand here today humble...
# 56       2013-Obama.txt  Thank you . Thank you so much . Vice President...
# 57       2017-Trump.txt  Chief Justice Roberts , President Carter , Pre...
# 58       2021-Biden.txt  Chief Justice Roberts , Vice President Harris ...

# %% [markdown]
# # 2. Vectorize the Text
#
# As we learnt in lecture, one way to vectorize text is using the [Term Frequency Inverse Document Frequency](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) (TF-IDF) featurizer.

# %%
vectorizer = TfidfVectorizer(max_df =0.95, min_df = 3, stop_words = 'english')
X = vectorizer.fit_transform(data['Text'])

# %% [markdown]
# Print the shape of your dataset. **Question**: What does each dimension stand for?

# %%
X.shape
# Out:
# (59, 3495)

# %%
words = vectorizer.get_feature_names()

# %% [markdown]
# Print the stop words. **Question**: Do you think this is a reasonable list of stopwords?

# %%
vectorizer.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %% [markdown]
# # 3. Running K-Means
#
# We will now run k-means to cluster the dataset, using sklearn's [KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html). Set `random_state=416`.

# %%
k = 5
kmeans = KMeans(n_clusters = k, random_state = 416)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=416, tol=0.0001, verbose=0)

# %% [markdown]
# For visualization purposes, let's add the cluster labels to the pandas dataframe.

# %%
data["Clusters k=%d" % k] = kmeans.labels_
data
# Out:
#                 File ID                                               Text  \
# 0   1789-Washington.txt  Fellow - Citizens of the Senate and of the Hou...
# 1   1793-Washington.txt  Fellow citizens , I am again called upon by th...
# 2        1797-Adams.txt  When it was first perceived , in early times ,...
# 3    1801-Jefferson.txt  Friends and Fellow Citizens : Called upon to u...
# 4    1805-Jefferson.txt  Proceeding , fellow citizens , to that qualifi...
# 5      1809-Madison.txt  Unwilling to depart from examples of the most ...
# 6      1813-Madison.txt  About to add the solemnity of an oath to the o...
# 7       1817-Monroe.txt  I should be destitute of feeling if I was not ...
# 8       1821-Monroe.txt  Fellow citizens , I shall not attempt to descr...
# 9        1825-Adams.txt  In compliance with an usage coeval with the ex...
# 10     1829-Jackson.txt  Fellow citizens , about to undertake the arduo...
# 11     1833-Jackson.txt  Fellow citizens , the will of the American peo...
# 12    1837-VanBuren.txt  Fellow citizens : The practice of all my prede...
# 13    1841-Harrison.txt  Called from a retirement which I had supposed ...
# 14        1845-Polk.txt  Fellow citizens , without solicitation on my p...
# 15      1849-Taylor.txt  Elected by the American people to the highest ...
# 26             4
# 27             4
# 28             4
# 29             2
# 30             4
# 31             2
# 32             2
# 33             2
# 34             4
# 35             4
# 36             2
# 37             2
# 38             2
# 39             2
# 40             2
# 41             2
# 42             0
# 43             0
# 44             0
# 45             0
# 46             0
# 47             0
# 48             0
# 49             0
# 50             0
# 51             0
# 52             0
# 53             0
# 54             0
# 55             0
# 56             0
# 57             0
# 58             0

# %% [markdown]
# **Questions**: What trends do you observe? What underlying patterns might the clustering algorithm have picked up on?
#
# To further analyze the clusters, let's print the most frequent words per cluster.

# %%
cluster_to_words_to_num_occurences = {}
for i in range(k):
    cluster_to_words_to_num_occurences[i] = {}
    for word in words:
        num_occurences = 0
        for _, text in data[(data["Clusters k=%d" % k] == i)]["Text"].iteritems():
            if word.lower() in text.lower().split(" "):
                num_occurences += 1
        cluster_to_words_to_num_occurences[i][word] = num_occurences

num_words = 10
for i in range(k):
    top_words = [(cluster_to_words_to_num_occurences[i][word], word) for word in cluster_to_words_to_num_occurences[i]]
    top_words.sort(reverse=True)
    print("Cluster %d: " % i, top_words[:num_words])
# Out:
# Cluster 0:  [(17, 'world'), (17, 'today'), (17, 'time'), (17, 'new'), (17, 'nation'), (17, 'long'), (17, 'life'), (17, 'great'), (17, 'god'), (17, 'america')]
# Cluster 1:  [(5, 'war'), (5, 'trust'), (5, 'public'), (5, 'proper'), (5, 'progress'), (5, 'place'), (5, 'nations'), (5, 'nation'), (5, 'government'), (5, 'fellow')]
# Cluster 2:  [(10, 'world'), (10, 'shall'), (10, 'men'), (10, 'life'), (10, 'know'), (10, 'great'), (9, 'time'), (9, 'purpose'), (9, 'new'), (9, 'nation')]
# Cluster 3:  [(13, 'union'), (13, 'rights'), (13, 'public'), (13, 'principles'), (13, 'powers'), (13, 'power'), (13, 'duties'), (13, 'country'), (13, 'constitution'), (13, 'confidence')]
# Cluster 4:  [(14, 'shall'), (14, 'government'), (14, 'country'), (14, 'constitution'), (14, 'citizens'), (13, 'united'), (13, 'states'), (13, 'public'), (13, 'political'), (13, 'policy')]

# %% [markdown]
# **Question**: What words are common across all clusters? What words are more unique to particular clusters?
#
# **Question**: Why do the clusters not correspond to meaningful topics of words?

# %% [markdown]
# # 4. Selecting K

# %% [markdown]
# Sklearn's KMeans classifier's `inertia_` property returns the objective function, or quality, of the clustering.
#
# **Question**: What would we expect the inertia to be when k=59?

# %%
ks = []
inertias = []
for k in range(1, 60, 2):
    # TODO: train a classifier with this k compute its quality
    ks.append(k)
    kmeans = KMeans(n_clusters = k).fit(X)
    inertias.append(kmeans.inertia_)

# %% [markdown]
# Graph it out

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(ks, inertias, marker='o')
ax.set_ylim(0, 50)
ax.set_xlabel("K")
ax.set_ylabel("Objective Function")
ax.set_xticks(range(0, ks[-1], 2), minor=True)
ax.grid(which='both')

# %% [markdown]
# **Question**: What appears to be the best value of k?

# %% [markdown]
# # 5. (Bonus) Exploring the Data!

# %% [markdown]
# The below function takes in a list of words and graphs their occurance in presidents' speeches over the years. Use it to identify trends in the data!

# %%
def words_over_time(words):
    cfd = ConditionalFreqDist(
        (target, int(fileid[:4]))
        for fileid in inaugural.fileids()
        for w in inaugural.words(fileid)
        for target in words
        if w.lower().startswith(target))
    cfd.plot()

# %%
plt.figure(figsize=(12, 5))
words_over_time(["war", "peace"])
